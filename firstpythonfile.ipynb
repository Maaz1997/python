# %%
5+5
# Out:
# 10

# %%
import pandas as pd
dataset=pd.read_csv("C:\Users\manoj\Desktop")
dataset
# Out:
#   File "<ipython-input-2-c2769b7dbd72>", line 2
#     dataset=pd.read_csv("C:\Users\manoj\Desktop")
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
dataset=pd.read_csv("C:\Users\manoj\Desktop/glass.csv")
dataset
# Out:
#   File "<ipython-input-3-414373f1aa69>", line 2
#     dataset=pd.read_csv("C:\Users\manoj\Desktop/glass.csv")
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df=pd.read_csv('glass.csv')
features=df.columns[:-1].tolist()
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e001a419c7d1> in <module>
# ----> 1 df=pd.read_csv('glass.csv')
#       2 features=df.columns[:-1].tolist()
#       3 df.head(10)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
df=pd.read_csv('glass.csv')
features=df.columns[:-1].tolist()
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-21ecd0a98fe0> in <module>
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('glass.csv')
#       3 features=df.columns[:-1].tolist()
#       4 df.head(10)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
import pandas as pd
df=pd.read_csv('glass.csv')
features=df.columns[:-1].tolist()
df.head(10)
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.00     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00     1
# 5  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26     1
# 6  1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.0  0.00     1
# 7  1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.0  0.00     1
# 8  1.51918  14.04  3.58  1.37  72.08  0.56  8.30  0.0  0.00     1
# 9  1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.0  0.11     1

# %%
import pandas as pd
df=pd.read_csv('glass.csv')
features=df.columns[:-1].tolist()

# %%
import pandas as pd
df=pd.read_csv('glass.csv')
features=df.columns[:-1].tolist()
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00     1
# 5    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26     1
# 6    1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.00  0.00     1
# 7    1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.00  0.00     1
# 8    1.51918  14.04  3.58  1.37  72.08  0.56  8.30  0.00  0.00     1
# 9    1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.00  0.11     1
# 10   1.51571  12.72  3.46  1.56  73.20  0.67  8.09  0.00  0.24     1
# 11   1.51763  12.80  3.66  1.27  73.01  0.60  8.56  0.00  0.00     1
# 12   1.51589  12.88  3.43  1.40  73.28  0.69  8.05  0.00  0.24     1
# ...

# %%
df.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516523   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
df['type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-d6b629113183> in <module>
# ----> 1 df['type'].value_counts()
#
# ...

# %%
df['Type'].value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %%
print((df[[0,1,2,3,4,5,6,7,8]]==0).sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-b1bde1af097b> in <module>
# ----> 1 print((df[[0,1,2,3,4,5,6,7,8]]==0).sum())
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import glass
boston=glass()
features=pd.DataFrame(boston.data,columns=boston.feature_name)
target=pd.DataFrame(boston.target,columns=['Type'])

data=pd.concat([features,target],axis=1)

data2=data.corr('pearson')
data2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-4e390aea2f76> in <module>
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.datasets import glass
#       5 boston=glass()
#       6 features=pd.DataFrame(boston.data,columns=boston.feature_name)
#
# ImportError: cannot import name 'glass' from 'sklearn.datasets' (C:\Users\manoj\Anaconda3\lib\site-packages\sklearn\datasets\__init__.py)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
boston=load_boston()
features=pd.DataFrame(boston.data,columns=boston.feature_name)
target=pd.DataFrame(boston.target,columns=['Type'])

data=pd.concat([features,target],axis=1)

data2=data.corr('pearson')
data2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#     101         try:
# --> 102             return self[key]
#     103         except KeyError:
#
# KeyError: 'feature_name'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e4d11b902368> in <module>
#       4 from sklearn.datasets import load_boston
#       5 boston=load_boston()
# ----> 6 features=pd.DataFrame(boston.data,columns=boston.feature_name)
#       7 target=pd.DataFrame(boston.target,columns=['Type'])
#       8
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#     102             return self[key]
#     103         except KeyError:
# --> 104             raise AttributeError(key)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
features=pd.DataFrame(df.data,columns=df.feature_name)
target=pd.DataFrame(df.target,columns=['Type'])

data=pd.concat([features,target],axis=1)

data2=data.corr('pearson')
data2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-13ff073ff723> in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 features=pd.DataFrame(df.data,columns=df.feature_name)
#       4 target=pd.DataFrame(df.target,columns=['Type'])
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
import sklearn.datasets
import numpy as np
import matplotlib.pyplot as plt
features=pd.DataFrame(df.data,columns=df.feature_name)
target=pd.DataFrame(df.target,columns=['Type'])

data=pd.concat([features,target],axis=1)

data2=data.corr('pearson')
data2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-a3075cd22e6f> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 features=pd.DataFrame(df.data,columns=df.feature_name)
#       5 target=pd.DataFrame(df.target,columns=['Type'])
#       6
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
df1=df.corr('pearson')
df1
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833  0.810403
# Na   -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087 -0.275442
# Mg   -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396 -0.443750
# Al   -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958 -0.259592
# Si   -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331 -0.208732
# K    -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000 -0.317836
# Ca    0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836  1.000000
# Ba   -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618 -0.112841
# Fe    0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719  0.124968
# Type -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054  0.000952
#
#             Ba        Fe      Type
# RI   -0.000386  0.143010 -0.164237
# Na    0.326603 -0.241346  0.502898
# Mg   -0.492262  0.083060 -0.744993
# ...

# %%
abs(df1['Type']).sort_values(ascending=False)
# Out:
# Type    1.000000
# Mg      0.744993
# Al      0.598829
# Ba      0.575161
# Na      0.502898
# Fe      0.188278
# RI      0.164237
# Si      0.151565
# K       0.010054
# Ca      0.000952
# Name: Type, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(df,color='green')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-54409abd861d> in <module>
#       1
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.scatter(df,color='green')
#       4
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
data1=pd.DataFrame(df['RI'])#load the values in alcohol column to data1
data2=pd.DataFrame(df['Na'])#load the values in malic_acid column to data2


final_data=pd.concat([data1,data2],axis=1)
final_data
# Out:
#           RI     Na
# 0    1.52101  13.64
# 1    1.51761  13.89
# 2    1.51618  13.53
# 3    1.51766  13.21
# 4    1.51742  13.27
# 5    1.51596  12.79
# 6    1.51743  13.30
# 7    1.51756  13.15
# 8    1.51918  14.04
# 9    1.51755  13.00
# 10   1.51571  12.72
# 11   1.51763  12.80
# 12   1.51589  12.88
# 13   1.51748  12.86
# 14   1.51763  12.61
# 15   1.51761  12.81
# 16   1.51784  12.68
# 17   1.52196  14.36
# 18   1.51911  13.90
# 19   1.51735  13.02
# 20   1.51750  12.82
# 21   1.51966  14.77
# 22   1.51736  12.78
# 23   1.51751  12.81
# 24   1.51720  13.38
# 25   1.51764  12.98
# 26   1.51793  13.21
# 27   1.51721  12.87
# 28   1.51768  12.56
# 29   1.51784  13.08
# ..       ...    ...
# 184  1.51115  17.38
# 185  1.51131  13.69
# 186  1.51838  14.32
# 187  1.52315  13.44
# 188  1.52247  14.86
# 189  1.52365  15.79
# 190  1.51613  13.88
# 191  1.51602  14.85
# 192  1.51623  14.20
# 193  1.51719  14.75
# 194  1.51683  14.56
# 195  1.51545  14.14
# 196  1.51556  13.87
# ...

# %%
plt.scatter(data1,data2,color='green')

# %%
data1_std = np.array(data1)
feature1 = (data1_std - data1_std.mean())/data1_std.std()

data2_std = np.array(data2)
feature2 = (data2_std - data2_std.mean())/data2_std.std()

print(f"Mean after standardization:\nAlcohol={feature1.mean()}, Malic acid={feature2.mean()}")

print(f"standard deviation after standardization:\nAlcohol={feature1.std()}, Malic acid={feature2.std()}")
# Out:
# Mean after standardization:
# Alcohol=-2.6711758454158907e-14, Malic acid=2.191393484119935e-15
# standard deviation after standardization:
# Alcohol=1.0000000000000002, Malic acid=1.0

# %%
plt.scatter(feature1,feature2,c='r')

# %%
from sklearn import preprocessing

std_scale = preprocessing.StandardScaler().fit([data1,data2])
df_standardize = std_scale.transform([data1,data2])
df_standardize
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-a3bf614d42e6> in <module>
#       1 from sklearn import preprocessing
#       2
# ----> 3 std_scale = preprocessing.StandardScaler().fit([data1,data2])
#       4 df_standardize = std_scale.transform([data1,data2])
#       5 df_standardize
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     643         # Reset internal state before fitting
#     644         self._reset()
# --> 645         return self.partial_fit(X, y)
#     646
#     647     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     667         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
#     668                         warn_on_dtype=True, estimator=self, dtype=FLOAT_DTYPES,
# ...

# %%
data1=pd.DataFrame(df['RI'])#load the values in alcohol column to data1
data2=pd.DataFrame(df['Na'])#load the values in malic_acid column to data2


final_data=pd.concat([data1,data2],axis=1)
final_data
